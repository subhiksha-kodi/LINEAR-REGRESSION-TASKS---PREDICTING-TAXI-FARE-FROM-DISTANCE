# %% [markdown]
# LINEAR REGRESSION (PREDICTING TAXI FARE FROM DISTANCE)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
df=pd.read_csv('regression_datasets_large.xlsx - Taxi_Fare.csv')

X=df[['Distance_km']]     #Machine learning models always expect X to be 2D. [] --> 1D, [[]] -->2D
y=df['Fare_Rs']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

trip_distance=15
#Whenever you pass input X to model.predict(), even if it’s just a single sample, you must provide it as a 2D array (rows × features).
predicted_fare=model.predict([[trip_distance]])

print(f'Predicted fair for {trip_distance} km is Rs. {predicted_fare[0]:.2f}')
print(f'Base Fare (Fixed cost): Rs. {model.intercept_:.2f}')
print(f'Fare per km: Rs. {model.coef_[0]:.2f}')
# Out:
# Predicted fair for 15 km is Rs. 465.49
# Base Fare (Fixed cost): Rs. 443.51
# Fare per km: Rs. 1.47
# d:\AI WORKFORCE\LINEAR REGRESSION TASKS (PREDICTING TAXI FARE FROM DISTANCE)\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test,y_test,color='red',label='Actual Fares')
plt.plot(X_test,y_pred,color='blue',linewidth=2,label='Regression Line (Predicted Fares)')
plt.xlabel('Distance (km)')
plt.ylabel('Taxi Fare Prediction')
plt.legend()
plt.grid()
plt.savefig('plots/linear_regression_graph.png')
plt.show()

# %%
print(f'R square: {r2_score(y_test,y_pred)}')
print(f'RMSE: {np.sqrt(mean_squared_error(y_test,y_pred))}')
# Out:
# R square: -0.06524973642943022
# RMSE: 219.56676813578954
